# %%
import boto3

# %%
boto3.client('ec2').describe_instances()
# Out:
# {'Reservations': [{'Groups': [],
#    'Instances': [{'AmiLaunchIndex': 0,
#      'ImageId': 'ami-0194c3e07668a7e36',
#      'InstanceId': 'i-05977cbc8ea1494c2',
#      'InstanceType': 't2.micro',
#      'KeyName': 'david_kr',
#      'LaunchTime': datetime.datetime(2021, 8, 19, 11, 35, 44, tzinfo=tzlocal()),
#      'Monitoring': {'State': 'disabled'},
#      'Placement': {'AvailabilityZone': 'eu-west-2a',
#       'GroupName': '',
#       'Tenancy': 'default'},
#      'PrivateDnsName': 'ip-172-31-3-79.eu-west-2.compute.internal',
#      'PrivateIpAddress': '172.31.3.79',
#      'ProductCodes': [],
#      'PublicDnsName': 'ec2-3-9-66-157.eu-west-2.compute.amazonaws.com',
#      'PublicIpAddress': '3.9.66.157',
#      'State': {'Code': 16, 'Name': 'running'},
#      'StateTransitionReason': '',
#      'SubnetId': 'subnet-cd723ab6',
#      'VpcId': 'vpc-5ebbe537',
#      'Architecture': 'x86_64',
#      'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
# ...
